# %%
from huggingface_hub import snapshot_download

# Sostituisci con l'ID del modello che ti interessa
#model_id = "microsoft/resnet-50" 
model_id = "edadaltocg/resnet50_cifar10"
local_dir = "./resnet50_local_instance"

# Questo scaricherà TUTTI i file necessari nella cartella specificata
snapshot_download(repo_id=model_id, local_dir=local_dir)

print("Download completato in locale!")
# Out:
# ...
# Fetching 7 files:   0%|          | 0/7 [00:00<?, ?it/s]
# Download completato in locale!

# %%
from transformers import AutoModelForImageClassification, AutoImageProcessor

percorso_locale = "./resnet50_local_instance"

# Il codice non farà nessuna richiesta di rete
processor = AutoImageProcessor.from_pretrained(percorso_locale)
model = AutoModelForImageClassification.from_pretrained(percorso_locale)



print("Modello caricato 100%_ offline!")
# Out:
# Loading weights:   0%|          | 0/320 [00:00<?, ?it/s]
# TimmWrapperForImageClassification LOAD REPORT from: ./resnet50_local_instance
# Key                     | Status   |
# ------------------------+----------+-------------------------------------------------------------------------------------------------
# timm_model.conv1.weight | MISMATCH | Reinit due to size mismatch - ckpt: torch.Size([64, 3, 3, 3]) vs model:torch.Size([64, 3, 7, 7])
#
# Notes:
# - MISMATCH	:ckpt weights were loaded, but they did not match the original empty weight shapes.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 7
#       5 # Il codice non farà nessuna richiesta di rete
#       6 processor = AutoImageProcessor.from_pretrained(percorso_locale)
# ----> 7 model = AutoModelForImageClassification.from_pretrained(percorso_locale)
#      11 print("Modello caricato 100%_ offline!")
# ...
